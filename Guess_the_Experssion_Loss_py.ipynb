# %% [markdown]
# <a href="https://colab.research.google.com/github/poojithavakada7-hue/Guess_the_Experssion_Loss/blob/main/Guess_the_Experssion_Loss_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs.get('loss') < 0.01:
            print("\nReached desired loss so cancelling training!")
            self.model.stop_training = True

Callbacks = myCallback()

model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[1])
])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-2.0, -1.0, 0.0, 1.0, 2.0, 3.0])
ys = np.array([-4.0, -1.0, 2.0, 5.0, 8.0, 11.0])

model.fit(xs, ys, epochs=1500, callbacks=[Callbacks])

answer = model.predict(np.array([10.0]))
print(answer)
